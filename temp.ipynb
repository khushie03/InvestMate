# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_news",
  "q": "Finance",
  "gl": "us",
  "hl": "en",
  "api_key": "73f0dd27edbec3a0902ab9996d54474b68e9b65fdbb85d2168af9448ecad699b"
}

search = GoogleSearch(params)
results = search.get_dict()
news_results = results["news_results"]

# %%
news_results
# Out:
# [{'position': 1,
#   'title': 'Why The Financial Markets Are The Only Real Check On Trump',
#   'source': {'name': 'Forbes',
#    'icon': 'https://lh3.googleusercontent.com/NIjzR9QHtZJllEvJIVkODXFQ7_rbx1BMBXx2rNUbttjuu9YWLIp2_juQaI9jJ2rDtzi6snbZ',
#    'authors': ['Sergei Klebnikov', 'Matt Schifrin']},
#   'link': 'https://www.forbes.com/sites/sergeiklebnikov/2025/03/01/why-the-financial-markets-are-the-only-real-check-on-trump/',
#   'thumbnail': 'https://imageio.forbes.com/specials-images/imageserve/67c0dfe83a0a9a6458ef0eff/Header-GettyImages-2189594675/0x0.jpg?format=jpg&height=1629&width=2400',
#   'thumbnail_small': 'https://news.google.com/api/attachments/CC8iK0NnNVNVMkZNVmtsWFZETlRUMWgzVFJESUF4aWdCU2dLTWdZSmNJTFRPQWM',
#   'date': '03/01/2025, 11:30 AM, +0000 UTC'},
#  {'position': 2,
#   'title': 'Stock market today: Nasdaq heads for worst week since 2023 as stocks lose steam',
#   'source': {'name': 'Yahoo Finance',
# ...

# %%
from serpapi import GoogleSearch

salary = input("Enter your monthly salary")
savings = input("Enter your monthly savings")
investment = input("Enter the amount invested by you in the current ")

t = []

stock_brokerages = [
    # India - Full-Service Brokers
    "Motilal Oswal", "ICICI Direct", "HDFC Securities", "Kotak Securities", 
    "Axis Direct", "Sharekhan", "Edelweiss Broking", "IIFL Securities", 
    "Reliance Securities", "SBICAP Securities", "Geojit Financial Services", 
    "Anand Rathi", "SMC Global Securities", "Nirmal Bang", "Karvy Stock Broking", 
    "Ventura Securities", "Choice Broking",

    # India - Discount Brokers & Fintech
    "Zerodha", "Angel One", "Upstox", "5Paisa", "Groww", "Alice Blue", 
    "Fyers", "Paytm Money", "TradeSmart", "Stoxkart", "Samco Securities", 
    "Zomato Stock Trading", "MStock by Mirae Asset", "Dhan",

    # USA - Major Brokerage Firms
    "Charles Schwab", "Fidelity Investments", "Robinhood", "TD Ameritrade", 
    "E*TRADE", "Interactive Brokers", "Merrill Edge", "Vanguard", "WeBull", 
    "Ally Invest", "TradeStation", "Zacks Trade", "M1 Finance", "Tastyworks",

    # Europe & UK
    "Saxo Bank", "DEGIRO", "eToro", "IG Group", "CMC Markets", "Plus500", 
    "XTB", "Swissquote", "Interactive Investor", "Hargreaves Lansdown", 
    "AJ Bell", "Libertex", "Flatex", "FinecoBank", "BinckBank", "Davy Group", 
    "Trade Republic", "JFD Brokers",

    # Australia & Asia
    "CommSec", "Westpac Online Investing", "ANZ Share Investing", 
    "Bell Direct", "Macquarie Online Trading", "Phillip Capital", 
    "Rakuten Securities", "Monex Group", "ThinkMarkets", "Tiger Brokers", 
    "Moomoo", "BOCOM International", "Haitong International", 
    "Shenwan Hongyuan Group",

    # Other Global & Forex Brokers
    "Ninety One", "Admiral Markets", "Vantage Markets", "FP Markets", 
    "Eightcap", "OANDA", "Pepperstone", "AxiTrader", "Forex.com", 
    "OctaFX", "IC Markets", "HotForex", "Exness", "XM Group"
]

Investment = input("Enter the place you invested the money ")
matches = [broker for broker in stock_brokerages if Investment in broker.lower()]
params = {
  "engine": "google_news",
  "q": "Finance" +" " + Investment,
  "gl": "us",
  "hl": "en",
  "api_key": "73f0dd27edbec3a0902ab9996d54474b68e9b65fdbb85d2168af9448ecad699b"
}

search = GoogleSearch(params)
results = search.get_dict()
news_results = results["news_results"]
for i in news_results:
  t.append(news_results)
import requests
from bs4 import BeautifulSoup

url = "https://m.economictimes.com/markets/stocks/recos/buy-angel-one-target-price-rs-3600-motilal-oswal-financial-services/articleshow/115861967.cms"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

text_content = soup.get_text()
print(text_content)
New_results = ""

for m in New_results[:8]:
  response = requests.get(m)
  soup = BeautifulSoup(response.text, "html.parser")
  text_content = soup.get_text()
  print(text_content)
  New_results = "Result from the news Link" + text_content

print(New_results)
import google.generativeai as genai
genai.configure(api_key="AIzaSyDVkQaXWifIjb9phPmz7o03LT_8RjpA52A")
#client = genai.Client(api_key="AIzaSyDVkQaXWifIjb9phPmz7o03LT_8RjpA52A")

model = genai.GenerativeModel("gemini-2.0-flash")
response = model.generate_content(f"""On the basis of the current salary {salary} and the
 amount of savings {savings} and the amount invested {investment} in {Investment}can you give me the details of the investment and if its profitable or not 
 and also give me the details of the stock . And the news {New_results}"""
 
)

print(response.text)
# Out:
# Buy Angel One, target price Rs 3,600:  Motilal Oswal Financial Services  - The Economic Times  Benchmarks Nifty22,173.2548.55FEATURED FUNDS★★★★★Canara Robeco ELSS Tax Saver Regular - Growth5Y Return16.62 %
#                 Invest NowFEATURED FUNDS★★★★★HSBC Large Cap Fund Direct-Growth5Y Return15.47 %
#                 Invest NowEnter search text:English EditionEnglish Editionहिन्दीગુજરાતીमराठीবাংলাಕನ್ನಡമലയാളംதமிழ்తెలుగు | Today's ePaper
#             			        My Watchlist
# ...

# %%
for i in news_results:
    print(i['link'])
# Out:
# https://www.financialexpress.com/money/motilal-oswals-4-funds-shine-despite-market-crash-check-their-1-year-returns-3761114/
# https://www.ndtvprofit.com/research-reports/buy-ltimindtree-reiterates-motilal-oswal-sees-35-upside-heres-why
# https://simplywall.st/stocks/in/diversified-financials/nse-motilalofs/motilal-oswal-financial-services-shares/news/those-who-invested-in-motilal-oswal-financial-services-nsemo
# https://www.livemint.com/companies/news/motilal-oswal-pe-majority-stake-in-api-maker-megafine-pharma-460-crore-11740490618224.html
# https://www.moneycontrol.com/news/business/markets/subhrajit-roy-joins-motilal-oswal-investment-banking-as-head-equity-capital-markets-12951795.html
# https://m.economictimes.com/markets/stocks/news/motilal-oswal-alternates-invests-rs-460-cr-for-majority-stake-in-mega-fine-pharma/articleshow/118561688.cms
# https://www.cnbctv18.com/personal-finance/motilal-oswal-mutual-fund-launches-active-momentum-scheme-nfo-19563628.htm
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://m.economictimes.com/markets/stocks/recos/buy-angel-one-target-price-rs-3600-motilal-oswal-financial-services/articleshow/115861967.cms"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

text_content = soup.get_text()
print(text_content)
# Out:
# Buy Angel One, target price Rs 3,600:  Motilal Oswal Financial Services  - The Economic Times  Benchmarks Nifty22,124.70-420.35FEATURED FUNDS★★★★★HSBC Large Cap Fund Direct-Growth5Y Return15.12 %
#                 Invest NowFEATURED FUNDS★★★★★Canara Robeco ELSS Tax Saver Regular - Growth5Y Return16.38 %
#                 Invest NowEnter search text:English EditionEnglish Editionहिन्दीગુજરાતીमराठीবাংলাಕನ್ನಡമലയാളംதமிழ்తెలుగు | Today's ePaper
#             			        My Watchlist
# ...

# %%
import http.client, urllib.parse

conn = http.client.HTTPSConnection('api.marketaux.com')

params = urllib.parse.urlencode({
    'api_token': 'tTycz4cTJHDIBwYWcxGSAHieVXWgc4B8U2PdrKwU',
    'symbols': 'Motilal Oswal',
    'limit': 50,
    })

conn.request('GET', '/v1/news/all?{}'.format(params))

res = conn.getresponse()
data = res.read()

print(data.decode('utf-8'))
# Out:
# {"warnings":["limit is higher than your plan allows"],"meta":{"found":0,"returned":0,"limit":3,"page":1},"data":[]}
